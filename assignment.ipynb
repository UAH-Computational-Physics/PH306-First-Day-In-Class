# %% [markdown]
# # PH 306 – Computational Physics
# ## First-Day Assignment
#
# **Name:**
#
# **Date:**
#
# ---
#
# ### Instructions
# 1. Open **`assignment.py`** and complete each function marked with `TODO`.
# 2. Return here and run all cells (**Run → Run All Cells**) to check your work.
# 3. Repeat until all checks pass.
# 4. **Commit and push** your changes to submit to CodeGrade.
#
# > **Note:** The autograder grades **`assignment.py`**, not this notebook.

# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt

import assignment

# %% [markdown]
# ---
#
# ## Problem 1 – Array Operations
#
# Implement `problem1_array_operations()` in `assignment.py`.
#
# It should return `(x, y)` where:
#
# - `x` is **100 evenly spaced values** from $0$ to $2\pi$ (inclusive)
# - `y = \sin(x)$
#
# *Hint:* Use [`numpy.linspace`](https://numpy.org/doc/stable/reference/generated/numpy.linspace.html) and [`numpy.sin`](https://numpy.org/doc/stable/reference/generated/numpy.sin.html).

# %%
# Call your function and inspect the first few values
x, y = assignment.problem1_array_operations()
print(f"x[:5] = {x[:5]}")
print(f"y[:5] = {y[:5]}")

# %%
# Visualize your result
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_xlabel("x")
ax.set_ylabel("sin(x)")
ax.set_title("Problem 1 – sin(x) over [0, 2π]")
plt.show()

# %%
### Public checks (same as autograder)
assert isinstance(x, np.ndarray), "x must be a NumPy array"
assert isinstance(y, np.ndarray), "y must be a NumPy array"
assert len(x) == 100, "x must contain 100 elements"
assert np.isclose(x[0], 0.0), "x must start at 0"
assert np.isclose(x[-1], 2 * np.pi), "x must end at 2π"
assert np.allclose(y[0], 0), "y[0] is not close to 0"
assert np.allclose(y[-1], 0), "y[-1] is not close to 0"
print("✓ Problem 1 checks passed")

# %% [markdown]
# ---
#
# ## Problem 2 – Numerical Integration
#
# Implement `problem2_numerical_integration()` in `assignment.py`.
#
# It should return `(result, error)` where `result` is the numerical value of
# $$\int_{-\infty}^{+\infty} e^{-x^2}\, dx$$
# and `error` is SciPy's absolute error estimate.
#
# *Hint:* Use [`scipy.integrate.quad`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.integrate.quad.html).
# The exact answer is $\sqrt{\pi} \approx 1.7725$.

# %%
# Call your function and inspect the result
result, error = assignment.problem2_numerical_integration()
print(f"result = {result}")
print(f"error  = {error}")
print(f"sqrt(π) = {np.sqrt(np.pi)}")

# %%
### Public checks (same as autograder)
assert isinstance(result, float), "result must be a float"
assert isinstance(error, float), "error must be a float"
assert np.isclose(result, np.sqrt(np.pi), rtol=1e-6), (
    f"result={result} is not close to sqrt(π)={np.sqrt(np.pi)}"
)
print("✓ Problem 2 checks passed")
